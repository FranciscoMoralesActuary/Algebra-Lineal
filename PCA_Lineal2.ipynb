# %% [markdown]
# # Aplicaciones del Algebra Lineal II
# ## Programación de PCA
# Codigo Elaborado por Morales Ramirez Angel Francisco

# %%
#Funcion para PCA
from sklearn.decomposition import PCA
#Funcion para Estadalizar Columnas
from sklearn.preprocessing import StandardScaler
#Libreria para graficas en 2 dimensiones
import matplotlib . pyplot as plt
#Libreria para calculos con visualizar datos
import seaborn as sns
#Libreria para calculos con matrices de datos
import pandas as pd
#Libreria para calculos con numericos
import numpy as np
#Libreria para graficas en 3 dimensiones
import plotly.express as px

# %%
#Introducimos nuestros datos
datos = {
"Estadistica": [10 , 9, 10, 8 , 9,7,10,5,10,8,6,10,10,9,10,9,9,7,7,6,9,7,8,8,6,8,9,9,9,10] ,
"Probabilidad": [10 , 9, 9 , 8 , 10,6,10,5,10,8,6,10,10,9,10,9,9,7,7,6,7,7,8,6,6,9,9,8,9,10] ,
"Ingles": [9 , 9, 10 , 6 , 6,10,10,5,9,8,6,5,10,9,8,9,9,7,7,6,9,7,8,7,5,9,9,9,10,10] ,
"Algebra": [8 , 8, 8 , 6 , 8,5,10,5,9,8,6,10,9,9,9,10,9,7,7,6,8,6,9,8,5,10,10,7,10,10] ,
"Demografia": [10 , 10, 10 , 10 , 10,10,10,5,10,8,6,10,10,9,10,10,9,7,7,6,8,6,10,8,5,8,10,8,9,10] ,
"Alumno": ["Francisco", "Diego", "Denilson", "Juan", "Tienda","Jesus","David","Yahir","Arturo","Hector",
           "Eduardo","Claudio","Paquito","Erick","Jessica","Rugerio","Luis","Ramon","Martin","Armenta","Ana",
           "Perla","Gabo","Esau","Adan","Apolinar","Marelyn","Oswaldo","Fernanda","Lucio"]
 }

# %%
#Los volvemos un DataFrame para poder operarlos
df = pd.DataFrame(datos)
df.head(5)
# Out:
#    Estadistica  Probabilidad  Ingles  Algebra  Demografia     Alumno
# 0           10            10       9        8          10  Francisco
# 1            9             9       9        8          10      Diego
# 2           10             9      10        8          10   Denilson
# 3            8             8       6        6          10       Juan
# 4            9            10       6        8          10     Tienda

# %%
#Elegimos solo las columnas Numericas
X = df [[ "Estadistica", "Probabilidad","Ingles","Algebra","Demografia"]]
X.head(5)
# Out:
#    Estadistica  Probabilidad  Ingles  Algebra  Demografia
# 0           10            10       9        8          10
# 1            9             9       9        8          10
# 2           10             9      10        8          10
# 3            8             8       6        6          10
# 4            9            10       6        8          10

# %%
# Estandarizar columnas
ss = StandardScaler()
df_estandarizado = ss.fit_transform(X)
df_estandarizado
# Out:
# array([[ 1.12022407,  1.14542732,  0.58841568,  0.        ,  0.82180998],
#        [ 0.42008403,  0.49707223,  0.58841568,  0.        ,  0.82180998],
#        [ 1.12022407,  0.49707223,  1.19712156,  0.        ,  0.82180998],
#        [-0.28005602, -0.15128285, -1.23770196, -1.22474487,  0.82180998],
#        [ 0.42008403,  1.14542732, -1.23770196,  0.        ,  0.82180998],
#        [-0.98019606, -1.44799302,  1.19712156, -1.83711731,  0.82180998],
#        [ 1.12022407,  1.14542732,  1.19712156,  1.22474487,  0.82180998],
#        [-2.38047614, -2.09634811, -1.84640784, -1.83711731, -2.18481189],
#        [ 1.12022407,  1.14542732,  0.58841568,  0.61237244,  0.82180998],
#        [-0.28005602, -0.15128285, -0.0202902 ,  0.        , -0.38083877],
#        [-1.6803361 , -1.44799302, -1.23770196, -1.22474487, -1.58348751],
#        [ 1.12022407,  1.14542732, -1.84640784,  1.22474487,  0.82180998],
#        [ 1.12022407,  1.14542732,  1.19712156,  0.61237244,  0.82180998],
# ...

# %%
#Lo volvemos un Data Frame
datos = pd.DataFrame(df_estandarizado)
datos.head(5)
# Out:
#           0         1         2         3        4
# 0  1.120224  1.145427  0.588416  0.000000  0.82181
# 1  0.420084  0.497072  0.588416  0.000000  0.82181
# 2  1.120224  0.497072  1.197122  0.000000  0.82181
# 3 -0.280056 -0.151283 -1.237702 -1.224745  0.82181
# 4  0.420084  1.145427 -1.237702  0.000000  0.82181

# %%
# PCA 2 componentes
pca2 = PCA(n_components=2, random_state=42)
pca_2 = pca2.fit_transform(datos)
pca_2
# Out:
# array([[ 1.67845264, -0.02959297],
#        [ 1.03157653,  0.28392314],
#        [ 1.59847109,  0.74975417],
#        [-0.83409586, -0.77340732],
#        [ 0.65983237, -1.59030648],
#        [-1.15396882,  2.09751822],
#        [ 2.44552321,  0.24637113],
#        [-4.64000567, -0.17684432],
#        [ 1.9490565 , -0.16533154],
#        [-0.38868834,  0.07708495],
#        [-3.22289989, -0.09220123],
#        [ 1.31620894, -2.49083506],
#        [ 2.17491935,  0.3821097 ],
#        [ 1.02841743,  0.16172804],
#        [ 1.72319364, -0.71277278],
#        [ 1.57278424,  0.01244601],
#        [ 1.02841743,  0.16172804],
#        [-1.80579412, -0.00755814],
#        [-1.80579412, -0.00755814],
#        [-3.22289989, -0.09220123],
#        [-0.12763818,  0.77482189],
#        [-2.35016093,  0.14172389],
#        [ 0.42944142, -0.08574055],
#        [-1.22624   , -0.00654447],
#        [-3.99312956, -0.49036044],
#        [ 0.68422663,  0.12114314],
#        [ 1.57278424,  0.01244601],
# ...

# %%
#Lo volvemos un data frame
dataframe_2 = pd.DataFrame({'PCA1': pca_2[:, 0], 'PCA2': pca_2[:, 1]})
dataframe_2.head()
# Out:
#        PCA1      PCA2
# 0  1.678453 -0.029593
# 1  1.031577  0.283923
# 2  1.598471  0.749754
# 3 -0.834096 -0.773407
# 4  0.659832 -1.590306

# %%
# Varianza total explicada
pca2.explained_variance_ratio_
# Out:
# array([0.77403485, 0.11304524])

# %%
# Suma de la varianza
pca2.explained_variance_ratio_.sum()
# Out:
# 0.887080091512276

# %%
# Crear grafico de la varianza explicada
sns.barplot(x = ['PCA1', 'PCA2'], y = pca2.explained_variance_ratio_)
# Out:
# <Axes: >

# %%
#Creamos el grafico de 2 PCA
sns.scatterplot(x = 'PCA1', y = 'PCA2', data = dataframe_2)
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %%
# PCA 3 Componentes
pca3 = PCA(n_components=3, random_state=42)
pca_3 = pca3.fit_transform(datos)
pca_3[:3]
# Out:
# array([[ 1.67845264, -0.02959297, -0.6440059 ],
#        [ 1.03157653,  0.28392314, -0.52353078],
#        [ 1.59847109,  0.74975417, -0.54313273]])

# %%
#Lo volvemos un DataFrame
dataframe_3 = pd.DataFrame({'PCA1': pca_3[:, 0], 'PCA2': pca_3[:, 1] , 'PCA3': pca_3[:, 2]})
dataframe_3.head()
# Out:
#        PCA1      PCA2      PCA3
# 0  1.678453 -0.029593 -0.644006
# 1  1.031577  0.283923 -0.523531
# 2  1.598471  0.749754 -0.543133
# 3 -0.834096 -0.773407 -1.556521
# 4  0.659832 -1.590306 -0.789968

# %%
# Varianza total explicada
pca3.explained_variance_ratio_
# Out:
# array([0.77403485, 0.11304524, 0.0676156 ])

# %%
# Suma de la varianza
pca3.explained_variance_ratio_.sum()
# Out:
# 0.9546956905500071

# %%
# Crear grafico de la varianza explicada
sns.barplot(x = ['PCA1', 'PCA2', 'PCA3'], y = pca3.explained_variance_ratio_)
# Out:
# <Axes: >

# %%
#Creamos el grafico de  3 PCA
fig = px.scatter_3d(dataframe_3, x='PCA1', y='PCA2', z='PCA3',
              )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Plus: Progamacion de Eigen Valores y Vectores

# %%
##Ingresamos la matriz A
A=np.array([[1, 0], [0, 1]])
##Calculamos Valores y Vectores Propios con la funcion lineal.eig
valores,vectores=np.linalg.eig(A)
##Imprimmos los valores
valores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0797a60da253> in <cell line: 2>()
#       1 ##Ingresamos la matriz A
# ----> 2 A=np.array([[1, 0], [0, 1]])
#       3 ##Calculamos Valores y Vectores Propios con la funcion lineal.eig
#       4 valores,vectores=np.linalg.eig(A)
#       5 ##Imprimmos los valores
#
# NameError: name 'np' is not defined

# %%
##Ingresamos la matriz A
A=np.array([[1, 0], [0, 1]])
##Calculamos Valores y Vectores Propios con la funcion lineal.eig
valores,vectores=np.linalg.eig(A)
##Imprimmos los vectores
vectores
# Out:
# array([[1., 0.],
#        [0., 1.]])
